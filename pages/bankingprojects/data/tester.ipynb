# %%
import pandas as pd

# %%
targ_eval = pd.read_csv("Application_Scorecard_Full_Table__25_Vars_.csv")
targ_eval.head()
# Out:
#       cust_id application_date  age  monthly_income employment_type  \
# 0  CUST000001       2022-04-13   50         15146.0        SALARIED
# 1  CUST000002       2022-12-15   30          9762.0        SALARIED
# 2  CUST000003       2022-09-28   59          3000.0        SALARIED
# 3  CUST000004       2022-04-17   48         17437.0   SELF-EMPLOYED
# 4  CUST000005       2022-03-13   56         15042.0        SALARIED
#
#   residential_status  credit_limit  debt_to_income  bureau_score  inq_6m  ...  \
# 0               RENT         15000            0.67         584.0       2  ...
# 1                OWN          5000            0.27         761.0       1  ...
# 2               RENT         15000            0.25         664.0       2  ...
# 3               RENT         20000            0.38         810.0       1  ...
# 4                OWN          5000            0.28         708.0       2  ...
#
#    emi_to_income_ratio  new_trades_3m  utilization_ratio  thin_file_flag  \
# ...

# %%
targ_eval['delinq_12m'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
import numpy as np

# %%
n_assets = 2
n_sim = 3

# %%
returns = np.random.randn(n_assets, n_sim)
returns
# Out:
# array([[-0.43534569,  0.44648301, -0.50749615],
#        [ 0.7092801 , -0.81150358,  1.79578368]])

# %%
returns.T
# Out:
# array([[-0.43534569,  0.7092801 ],
#        [ 0.44648301, -0.81150358],
#        [-0.50749615,  1.79578368]])

# %%
rand = np.random.randn(n_assets)
rand
# Out:
# array([0.22002331, 0.56756174])

# %%
sum(rand)
# Out:
# 0.787585041189788

# %%
weights = rand/sum(rand)
weights
# Out:
# array([0.27936451, 0.72063549])

# %%
weights.shape
# Out:
# (2,)

# %%
rets = np.mean(returns, axis=1)
rets
# Out:
# array([-0.16545295,  0.56452007])

# %%
returns.T
# Out:
# array([[-0.43534569,  0.7092801 ],
#        [ 0.44648301, -0.81150358],
#        [-0.50749615,  1.79578368]])
