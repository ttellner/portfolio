# %%
import pandas as pd

# %%
pwd
# Out:
# 'd:\\Repos\\portfolio'

# %%
path_to_file = 'samplefile.txt'
text_to_write = 'This is an example sentence for a new file.'
with open(path_to_file, 'w') as f:
   f.write(text_to_write)
